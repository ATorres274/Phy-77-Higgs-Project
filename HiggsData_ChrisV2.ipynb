# %%
# %pip install uproot3
# Out:
# ...
#      |████████████████████████████████| 117 kB 2.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 87 kB 6.7 MB/s  eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import uproot3 as ur
file11 = ur.open("http://moller.physics.berkeley.edu/~yury/Phys129/tree_TYPE_DATA_2011.root")
file12 = ur.open("http://moller.physics.berkeley.edu/~yury/Phys129/tree_TYPE_DATA_2012.root")



print('Accessing file11 contents: \n')
      
print('file11 classnames: ',file11.classnames(), '\n')
print('file11 keyes: ',file11.keys(), '\n')
tree11 = file11["TYPE_DATA"]
print('tree11 [TYPE_DATA] keyes: \n',tree11.keys(), '\n')


      
print('\n\nAccessing file12 contents:\n')
      
print('file12 classnames: ',file12.classnames(), '\n')
print('file12 keyes: ',file12.keys(), '\n')
tree12 = file12["tree_TYPE_DATA"]
print('tree12 [tree_TYPE_DATA] keys: \n',tree12.keys(), '\n')
# Out:
# Accessing file11 contents:
#
# file11 classnames:  [(b'TYPE_DATA;1', 'TTree')]
#
# file11 keyes:  [b'TYPE_DATA;1']
#
# tree11 [TYPE_DATA] keyes:
#  [b'RunNumber', b'EventNumber', b'lbn', b'JetMultiplicity', b'averageIntPerXing', b'PV_n', b'vtx_z', b'invariant_mass', b'ph_pt_leading', b'ph_pt_subleading', b'ph_eta_corrected_leading', b'ph_eta_corrected_subleading', b'ph_etas2_leading', b'ph_etas2_subleading', b'ph_phi_leading', b'ph_phi_subleading', b'ph_E_corrected_leading', b'ph_E_corrected_subleading', b'ph_isConv_leading', b'ph_isConv_subleading', b'categ_Model5Categories', b'categ_Model10Categories', b'categ_ModelHighPttEtaConvVBF', b'categ_ModelHighPttGoodBadVBF', b'categ_conversion']
#
#
#
# Accessing file12 contents:
#
# file12 classnames:  [(b'tree_TYPE_DATA;1', 'TTree')]
#
# file12 keyes:  [b'tree_TYPE_DATA;1']
#
# tree12 [tree_TYPE_DATA] keys:
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas

print(tree12)
#df = tree.pandas.df(["invariant_mass","ph*","categ*"])
df12 = tree12.pandas.df()
df12
# Out:
# <TTree b'tree_TYPE_DATA' at 0x7fb2d5a035d0>
#        RunNumber  EventNumber  invariant_mass      vtx_z  ph_pt_leading  \
# entry
# 0         200842     25404000      114.236508   8.078268   55578.660156
# 1         200863      2063048      150.575453  -1.139064   65689.929688
# 2         200863      2205667      111.802937  47.500282   50850.523438
# 3         200863      3903104      111.692742  12.596541   49765.097656
# 4         200863      4510879      108.769898 -26.890108   61681.742188
# ...          ...          ...             ...        ...            ...
# 35246     205113     42198958      136.420766  14.884994   49885.582031
# 35247     205113     42603013      136.439156 -10.336266   61627.238281
# 35248     205113     42683792      105.423867  73.684433   52627.847656
# 35249     205113     42961483      101.747070 -34.146641   56566.667969
# 35250     205113     43025064      143.255484 -30.441101   78781.429688
#
# ...

# %%
df11 = tree11.pandas.df()
df11
# Out:
#        RunNumber  EventNumber  lbn  JetMultiplicity  averageIntPerXing  PV_n  \
# entry
# 0         178044     59092042  610                0               4.69     3
# 1         178044     10545724  169                1               7.22     6
# 2         178044      4030696  117                1               7.70     4
# 3         178044     18669075  228                0               6.70     8
# 4         178044     19086286  231                1               6.68     8
# ...          ...          ...  ...              ...                ...   ...
# 23783     191933     61490596  284                1              13.49    12
# 23784     191933     62339309  287                1              13.44    11
# 23785     191933     62600643  288                0              13.43    10
# 23786     191933     63370355  290                0              13.39    12
# 23787     191933     63769848  292                0              13.37    10
#
# ...

# %%
#Combine df11 & df12
df11_df12_invMass = np.concatenate((df11["invariant_mass"], df12["invariant_mass"]))

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
from scipy.optimize import curve_fit
# %matplotlib inline

y, bin_edges = np.histogram(df11_df12_invMass, range=(100,160),bins=30)

#create an array of bin centers
x = 0.5*(bin_edges[1:] + bin_edges[:-1])

#avoid zero error, create a minimum error of 1
error_y = np.sqrt(y)
error_y = [max(error,1) for error in error_y]

#plot
plt.errorbar(x,y,error_y, fmt='o', label = 'Data')
plt.title('Distributions of the invariant mass')
plt.xlabel('mγγ GeV')
plt.ylabel('Events')
plt.legend()

#Curve fitting: define a 4th order polynomial:

def model(x, a0, a1, a2, a3, a4):
    f = a0 + a1*x + a2*x**2 + a3*x**3 + a4*x**4
    return f

#From scipy.org & Workshop 7
popt, pcov = curve_fit(model, x, y)

#Display the useful data from this fit
print('Background Curve Fit Data:\n')

#Save the coefficients of the polynomial
a0 = popt[0]
a1 = popt[1]
a2 = popt[2]
a3 = popt[3]
a4 = popt[4]
error_a0 = np.sqrt(pcov[0,0])
error_a1 = np.sqrt(pcov[1,1])
error_a2 = np.sqrt(pcov[2,2])
error_a3 = np.sqrt(pcov[3,3])
error_a4 = np.sqrt(pcov[4,4])

print('Values that maximize 𝜒2 for Bkg:')
print('a0= %.3f ± %.2f' % (a0 , error_a0)       )
print('a1= %.3f ± %.3f' % (a1 , error_a1)       )
print('a2= %f ± %.5f'   % (a2 , error_a2)       )
print('a3= %f ± %f'   % (a3 , error_a3)       )
print('a4= %.7f ± %f' % (a4 , error_a4), '\n'  )

chi_squared_bkg = np.sum(((model(x, *popt)-y)/sigma)**2)
reduced_chi_squared_bkg = (chi_squared_bkg)/(len(x)-len(popt))

print('Bkg fit 𝜒2 = %.2f' % chi_squared_bkg)
print ('Reduced 𝜒2 = %f' % reduced_chi_squared_bkg, '\n')

#plot the fit over data
plt.plot(x, model(x, *popt), 'r--', label= 'Bkg (4th order polynomial)')

print()

#Curve Fitting with Signal+background:
print('Signal + Background Curve Fit Data:\n')

mean = 126
sigma = (3.9 / (2*np.sqrt(2*np.log(2))))
A = 126.5

#define a 4th order polynomial plus signal
def model2(x, a0, a1, a2, a3, a4):
    return a0 + a1*x + a2*x**2 + a3*x**3 + a4*x**4 + 126.5*np.e**( (-(x-126)**2) / (2*(3.9 / (2*np.sqrt(2*np.log(2))))**2) )

#fit a curve to the Sig+Bkg function
par, cov = curve_fit(model2, x, y)

#Save the coefficients of the polynomial
a0 = par[0]
a1 = par[1]
a2 = par[2]
a3 = par[3]
a4 = par[4]
error_a0 = np.sqrt(cov[0,0])
error_a1 = np.sqrt(cov[1,1])
error_a2 = np.sqrt(cov[2,2])
error_a3 = np.sqrt(cov[3,3])
error_a4 = np.sqrt(cov[4,4])

print('Values that maximize 𝜒2 for Sig+Bkg:')
print('a0= %.3f ± %.2f' % (a0 , error_a0)       )
print('a1= %.3f ± %.4f' % (a1 , error_a1)       )
print('a2= %f ± %.5f'   % (a2 , error_a2)       )
print('a3= %f ± %f'   % (a3 , error_a3)       )
print('a4= %.7f ± %f' % (a4 , error_a4), '\n'  )

chi_squared_sigBkg = np.sum(((model2(x, *par)-y)/sigma)**2)
reduced_chi_squared_sigBkg = (chi_squared_sigBkg)/(len(x)-len(par))

print('Sig+Bkg fit 𝜒2 = %.2f' % chi_squared_sigBkg)
print ('Reduced 𝜒2 = %f' % reduced_chi_squared_sigBkg, '\n')


#plot the fit over data
plt.plot(x, model2(x, *par), 'r-', label= 'Sig+Bkg (4th order polynomial)')
plt.legend()
plt.show()
# Out:
# Background Curve Fit Data:
#
# Values that maximize 𝜒2 for Bkg:
# a0= 93096.854 ± 37990.92
# a1= -2561.002 ± 1192.835
# a2= 28.063009 ± 13.94670
# a3= -0.140654 ± 0.071976
# a4= 0.0002675 ± 0.000138
#
# Bkg fit 𝜒2 = 19277.23
# Reduced 𝜒2 = 771.089078
#
#
# Signal + Background Curve Fit Data:
#
# Values that maximize 𝜒2 for Sig+Bkg:
# a0= 60453.113 ± 30699.82
# a1= -1506.082 ± 963.9083
# a2= 15.416261 ± 11.27006
# a3= -0.074013 ± 0.058162
# a4= 0.0001373 ± 0.000112
#
# Sig+Bkg fit 𝜒2 = 12588.49
# Reduced 𝜒2 = 503.539602

# %%
#Repeat above for weighted values
